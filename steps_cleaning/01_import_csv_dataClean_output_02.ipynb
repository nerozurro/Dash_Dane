# %% [markdown]
# ## 1. Libraries and import file

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
df2013 = pd.read_csv('/content/drive/MyDrive/Abastecimiento_Proyecto/dataDanecsv/abastecimiento_2013.csv')
df2014 = pd.read_csv('/content/drive/MyDrive/Abastecimiento_Proyecto/dataDanecsv/abastecimiento_2014.csv')
df2015 = pd.read_csv('/content/drive/MyDrive/Abastecimiento_Proyecto/dataDanecsv/abastecimiento_2015.csv')
df2016 = pd.read_csv('/content/drive/MyDrive/Abastecimiento_Proyecto/dataDanecsv/abastecimiento_2016.csv')
df2017 = pd.read_csv('/content/drive/MyDrive/Abastecimiento_Proyecto/dataDanecsv/abastecimiento_2017.csv')
df2018 = pd.read_csv('/content/drive/MyDrive/Abastecimiento_Proyecto/dataDanecsv/abastecimiento_2018.csv')
df2019 = pd.read_csv('/content/drive/MyDrive/Abastecimiento_Proyecto/dataDanecsv/abastecimiento_2019.csv')
df2020 = pd.read_csv('/content/drive/MyDrive/Abastecimiento_Proyecto/dataDanecsv/abastecimiento_2020.csv')
df2021 = pd.read_csv('/content/drive/MyDrive/Abastecimiento_Proyecto/dataDanecsv/abastecimiento_2021.csv')

# %%
print(df2013.columns)
print(df2014.columns)
print(df2015.columns)
print(df2016.columns)
print(df2017.columns)
print(df2018.columns)
print(df2019.columns)
print(df2020.columns)
print(df2021.columns)
# Out:
# Index(['Unnamed: 0', 'Cuidad, Mercado Mayorista', 'Fecha',
#        'Código Departamento', 'Código Municipio', 'Departamento Proc.',
#        'Municipio Proc.', 'Grupo', 'Alimento', 'Cant Kg', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')
# Index(['Unnamed: 0', 'Cuidad, Mercado Mayorista', 'Fecha',
#        'Código Departamento', 'Código Municipio', 'Departamento Proc.',
#        'Municipio Proc.', 'Grupo', 'Alimento', 'Cant Kg', 'Unnamed: 9'],
#       dtype='object')
# Index(['Unnamed: 0', 'Cuidad, Mercado Mayorista', 'Fecha',
#        'Código Departamento', 'Código Municipio', 'Departamento Proc.',
#        'Municipio Proc.', 'Grupo', 'Alimento', 'Cant Kg', 'Unnamed: 9'],
#       dtype='object')
# Index(['Unnamed: 0', 'Cuidad, Mercado Mayorista', 'Fecha',
#        'Código Departamento', 'Código Municipio', 'Departamento Proc.',
#        'Municipio Proc.', 'Grupo', 'Alimento', 'Cant Kg', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')
# ...

# %%
# df2021.head()

# %%
# len(df)
# # df.reset_index(inplace=True)
# df.head()

# %% [markdown]
# ##2. Data Cleaning

# %% [markdown]
# ### 2.1 AdjustData

# %%
df2013.columns = ['delete1', 'destino_ciudad_mercado', 'fecha', 'procedencia_codigo_departamento', 'procedencia_codigo_municipio', 'procedencia_departamento', 'procedencia_municipio', 'grupo', 'alimento', 'cantidad_kg', 'delete2', 'delete3']
df2016.columns = ['delete1', 'destino_ciudad_mercado', 'fecha', 'procedencia_codigo_departamento', 'procedencia_codigo_municipio', 'procedencia_departamento', 'procedencia_municipio', 'grupo', 'alimento', 'cantidad_kg', 'delete2', 'delete3']
df2018.columns = ['delete1', 'destino_ciudad_mercado', 'fecha', 'procedencia_codigo_departamento', 'procedencia_codigo_municipio', 'procedencia_departamento', 'procedencia_municipio', 'grupo', 'alimento', 'cantidad_kg', 'delete2', 'delete3']



df2014.columns = ['delete1', 'destino_ciudad_mercado', 'fecha', 'procedencia_codigo_departamento', 'procedencia_codigo_municipio', 'procedencia_departamento', 'procedencia_municipio', 'grupo', 'alimento', 'cantidad_kg', 'delete2']
df2015.columns = ['delete1', 'destino_ciudad_mercado', 'fecha', 'procedencia_codigo_departamento', 'procedencia_codigo_municipio', 'procedencia_departamento', 'procedencia_municipio', 'grupo', 'alimento', 'cantidad_kg', 'delete2']
df2017.columns = ['delete1', 'destino_ciudad_mercado', 'fecha', 'procedencia_codigo_departamento', 'procedencia_codigo_municipio', 'procedencia_departamento', 'procedencia_municipio', 'grupo', 'alimento', 'cantidad_kg', 'delete2']

df2019.columns = ['delete1', 'destino_ciudad_mercado', 'fecha', 'procedencia_codigo_departamento', 'procedencia_codigo_municipio', 'procedencia_departamento', 'procedencia_municipio', 'grupo', 'alimento', 'cantidad_kg', 'delete2']
df2020.columns = ['delete1', 'destino_ciudad_mercado', 'fecha', 'procedencia_codigo_departamento', 'procedencia_codigo_municipio', 'procedencia_departamento', 'procedencia_municipio', 'grupo', 'alimento', 'cantidad_kg', 'delete2']
df2021.columns = ['delete1', 'destino_ciudad_mercado', 'fecha', 'procedencia_codigo_departamento', 'procedencia_codigo_municipio', 'procedencia_departamento', 'procedencia_municipio', 'grupo', 'alimento', 'cantidad_kg', 'delete2']

# %%
df2013.drop(['delete1', 'delete2', 'delete3'], inplace=True, axis=1)
df2014.drop(['delete1', 'delete2'], inplace=True, axis=1)
df2015.drop(['delete1', 'delete2'], inplace=True, axis=1)
df2016.drop(['delete1', 'delete2', 'delete3'], inplace=True, axis=1)
df2017.drop(['delete1', 'delete2'], inplace=True, axis=1)
df2018.drop(['delete1', 'delete2', 'delete3'], inplace=True, axis=1)
df2019.drop(['delete1', 'delete2'], inplace=True, axis=1)
df2020.drop(['delete1', 'delete2'], inplace=True, axis=1)
df2021.drop(['delete1', 'delete2'], inplace=True, axis=1)

# %% [markdown]
# ### Show adjusted Data columns

# %%
df2013.head()
# Out:
#      destino_ciudad_mercado  ... cantidad_kg
# 0  Bogotá, D.C., Corabastos  ...       600.0
# 1  Bogotá, D.C., Corabastos  ...      2600.0
# 2  Bogotá, D.C., Corabastos  ...      3000.0
# 3  Bogotá, D.C., Corabastos  ...      1800.0
# 4  Bogotá, D.C., Corabastos  ...      2600.0
#
# [5 rows x 9 columns]

# %%
df2014.head()
# Out:
#      destino_ciudad_mercado       fecha  ...            alimento cantidad_kg
# 0  Bogotá, D.C., Corabastos  2014-01-01  ...     Lechuga Batavia      3700.0
# 1  Bogotá, D.C., Corabastos  2014-01-01  ...  Hortalizas de hoja       700.0
# 2  Bogotá, D.C., Corabastos  2014-01-01  ...               Fresa      2500.0
# 3  Bogotá, D.C., Corabastos  2014-01-01  ...     Lechuga Batavia      4150.0
# 4  Bogotá, D.C., Corabastos  2014-01-01  ...  Hortalizas de hoja       200.0
#
# [5 rows x 9 columns]

# %%
df2015.head()
# Out:
#          destino_ciudad_mercado       fecha  ...          alimento cantidad_kg
# 0  Barranquilla, Barranquillita  2015-01-01  ...  Naranja Valencia       650.0
# 1  Barranquilla, Barranquillita  2015-01-01  ...        Papa única     11750.0
# 2  Barranquilla, Barranquillita  2015-01-01  ...         Zanahoria      1620.0
# 3  Barranquilla, Barranquillita  2015-01-01  ...         Remolacha       240.0
# 4  Barranquilla, Barranquillita  2015-01-01  ...           Repollo       420.0
#
# [5 rows x 9 columns]

# %%
df2016.head()
# Out:
#      destino_ciudad_mercado       fecha  ...               alimento cantidad_kg
# 0  Bogotá, D.C., Corabastos  2016-01-01  ...                   Yuca      7800.0
# 1  Bogotá, D.C., Corabastos  2016-01-01  ...                   Yuca      7950.0
# 2  Bogotá, D.C., Corabastos  2016-01-01  ...               Cilantro      2000.0
# 3  Bogotá, D.C., Corabastos  2016-01-01  ...  Arveja verde en vaina      9000.0
# 4  Bogotá, D.C., Corabastos  2016-01-01  ...                   Yuca      7620.0
#
# [5 rows x 9 columns]

# %%
df2017.head()
# Out:
#   destino_ciudad_mercado       fecha  ...          alimento cantidad_kg
# 0        Armenia, Mercar  2017-01-02  ...         Remolacha       480.0
# 1        Armenia, Mercar  2017-01-02  ...   Chócolo mazorca      1500.0
# 2        Armenia, Mercar  2017-01-02  ...  Cebolla Cabezona      2250.0
# 3        Armenia, Mercar  2017-01-02  ...         Zanahoria      2100.0
# 4        Armenia, Mercar  2017-01-02  ...             Fresa       300.0
#
# [5 rows x 9 columns]

# %%
df2018.head()
# Out:
#   destino_ciudad_mercado       fecha  ...       alimento cantidad_kg
# 0        Armenia, Mercar  2018-01-02  ...   Papa suprema      9750.0
# 1        Armenia, Mercar  2018-01-02  ...    Papa capira      5000.0
# 2        Armenia, Mercar  2018-01-02  ...   Papa suprema     28000.0
# 3        Armenia, Mercar  2018-01-02  ...   Papa suprema      9750.0
# 4        Armenia, Mercar  2018-01-02  ...  Cebolla junca      1400.0
#
# [5 rows x 9 columns]

# %%
df2019.head()
# Out:
#   destino_ciudad_mercado       fecha  ...               alimento cantidad_kg
# 0        Armenia, Mercar  2019-01-02  ...           Papa suprema     10000.0
# 1        Armenia, Mercar  2019-01-02  ...           Papa suprema     10000.0
# 2        Armenia, Mercar  2019-01-02  ...              Piña gold      1600.0
# 3        Armenia, Mercar  2019-01-02  ...  Arveja verde en vaina      1000.0
# 4        Armenia, Mercar  2019-01-02  ...           Papa criolla      6000.0
#
# [5 rows x 9 columns]

# %%
df2020.head()
# Out:
#   destino_ciudad_mercado     fecha  ...        alimento cantidad_kg
# 0        Armenia, Mercar  02/01/20  ...     Papa capira      3000.0
# 1        Armenia, Mercar  02/01/20  ...    Papa suprema      7000.0
# 2        Armenia, Mercar  02/01/20  ...    Papa suprema     10000.0
# 3        Armenia, Mercar  02/01/20  ...       Piña gold      1500.0
# 4        Armenia, Mercar  02/01/20  ...  Papaya Maradol      6000.0
#
# [5 rows x 9 columns]

# %%
df2021.head()
# Out:
#   destino_ciudad_mercado       fecha  ...            alimento cantidad_kg
# 0        Armenia, Mercar  2021-01-02  ...      Carne de cerdo      3240.0
# 1        Armenia, Mercar  2021-01-02  ...        Carne de res     15640.0
# 2        Armenia, Mercar  2021-01-02  ...        Papa suprema      8000.0
# 3        Armenia, Mercar  2021-01-02  ...         Papa capira      2000.0
# 4        Armenia, Mercar  2021-01-02  ...  Papa parda pastusa     10000.0
#
# [5 rows x 9 columns]

# %% [markdown]
# ### 2.2 Select df to clean

# %%
# frames = [df2013, df2014, df2015, df2016, df2017, df2018, df2019, df2020, df2021]
# df = pd.concat(frames)
# df.reset_index(inplace=True)
# df.drop(['index'], inplace=True, axis=1)


df=df2021

# %%
len(df)
# Out:
# 1129666

# %%
df.head()
# Out:
#   destino_ciudad_mercado       fecha  ...            alimento cantidad_kg
# 0        Armenia, Mercar  2021-01-02  ...      Carne de cerdo      3240.0
# 1        Armenia, Mercar  2021-01-02  ...        Carne de res     15640.0
# 2        Armenia, Mercar  2021-01-02  ...        Papa suprema      8000.0
# 3        Armenia, Mercar  2021-01-02  ...         Papa capira      2000.0
# 4        Armenia, Mercar  2021-01-02  ...  Papa parda pastusa     10000.0
#
# [5 rows x 9 columns]

# %%
# df2013 = []
# df2014 = []
# df2015 = []
# df2016 = []
# df2017 = []
# df2018 = []
# df2019 = []
# df2020 = []
# df2021 = []

# %%
df.head(20)
# Out:
#    destino_ciudad_mercado       fecha  ...            alimento cantidad_kg
# 0         Armenia, Mercar  2021-01-02  ...      Carne de cerdo      3240.0
# 1         Armenia, Mercar  2021-01-02  ...        Carne de res     15640.0
# 2         Armenia, Mercar  2021-01-02  ...        Papa suprema      8000.0
# 3         Armenia, Mercar  2021-01-02  ...         Papa capira      2000.0
# 4         Armenia, Mercar  2021-01-02  ...  Papa parda pastusa     10000.0
# 5         Armenia, Mercar  2021-01-02  ...        Papa suprema     10000.0
# 6         Armenia, Mercar  2021-01-02  ...         Papa capira      3000.0
# 7         Armenia, Mercar  2021-01-02  ...        Papa suprema      7000.0
# 8         Armenia, Mercar  2021-01-02  ...       Papa superior     10000.0
# 9         Armenia, Mercar  2021-01-02  ...                Mora      1300.0
# 10        Armenia, Mercar  2021-01-02  ...       Cebolla junca      1500.0
# ...

# %%
df.tail()
# Out:
#         destino_ciudad_mercado  ... cantidad_kg
# 1129661     Villavicencio, CAV  ...       400.0
# 1129662     Villavicencio, CAV  ...       500.0
# 1129663     Villavicencio, CAV  ...      3000.0
# 1129664     Villavicencio, CAV  ...      1000.0
# 1129665     Villavicencio, CAV  ...      1000.0
#
# [5 rows x 9 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1129666 entries, 0 to 1129665
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   destino_ciudad_mercado           1129666 non-null  object
#  1   fecha                            1129666 non-null  object
#  2   procedencia_codigo_departamento  1129666 non-null  object
#  3   procedencia_codigo_municipio     1129666 non-null  object
#  4   procedencia_departamento         1129666 non-null  object
#  5   procedencia_municipio            1129666 non-null  object
#  6   grupo                            1129666 non-null  object
#  7   alimento                         1129666 non-null  object
#  8   cantidad_kg                      1129666 non-null  float64
# dtypes: float64(1), object(8)
# memory usage: 77.6+ MB
# None

# %% [markdown]
# ### 2.3 Clean df

# %%
df.loc[df['cantidad_kg']=='Cant Kg']
# Out:
# Empty DataFrame
# Columns: [destino_ciudad_mercado, fecha, procedencia_codigo_departamento, procedencia_codigo_municipio, procedencia_departamento, procedencia_municipio, grupo, alimento, cantidad_kg]
# Index: []

# %%
# 
df['cantidad_kg'] = df['cantidad_kg'].fillna(0)

# %%
df = df.astype({'cantidad_kg': int})

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1129666 entries, 0 to 1129665
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   destino_ciudad_mercado           1129666 non-null  object
#  1   fecha                            1129666 non-null  object
#  2   procedencia_codigo_departamento  1129666 non-null  object
#  3   procedencia_codigo_municipio     1129666 non-null  object
#  4   procedencia_departamento         1129666 non-null  object
#  5   procedencia_municipio            1129666 non-null  object
#  6   grupo                            1129666 non-null  object
#  7   alimento                         1129666 non-null  object
#  8   cantidad_kg                      1129666 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 77.6+ MB
# None

# %%
df['procedencia_codigo_departamento'] = df['procedencia_codigo_departamento'].str.replace("'", '')
df['procedencia_codigo_municipio'] = df['procedencia_codigo_municipio'].str.replace("'", '')

# %%
df.head()
# Out:
#   destino_ciudad_mercado       fecha  ...            alimento cantidad_kg
# 0        Armenia, Mercar  2021-01-02  ...      Carne de cerdo        3240
# 1        Armenia, Mercar  2021-01-02  ...        Carne de res       15640
# 2        Armenia, Mercar  2021-01-02  ...        Papa suprema        8000
# 3        Armenia, Mercar  2021-01-02  ...         Papa capira        2000
# 4        Armenia, Mercar  2021-01-02  ...  Papa parda pastusa       10000
#
# [5 rows x 9 columns]

# %%
df['procedencia_pais'] = ['_Importado' if x=='OTRO' else 'Colombia' for x in df['procedencia_departamento']]
df['procedencia_departamento'] = ['_Importado' if x=='OTRO' else x for x in df['procedencia_departamento']]
df['procedencia_municipio'] = df['procedencia_municipio'] + ', ' + df['procedencia_departamento']
df.head()
# Out:
#   destino_ciudad_mercado       fecha  ... cantidad_kg procedencia_pais
# 0        Armenia, Mercar  2021-01-02  ...        3240         Colombia
# 1        Armenia, Mercar  2021-01-02  ...       15640         Colombia
# 2        Armenia, Mercar  2021-01-02  ...        8000         Colombia
# 3        Armenia, Mercar  2021-01-02  ...        2000         Colombia
# 4        Armenia, Mercar  2021-01-02  ...       10000         Colombia
#
# [5 rows x 10 columns]

# %%
df.groupby(['grupo', 'alimento'])['cantidad_kg'].sum()
# Out:
# grupo                  alimento
# CARNES                 Carne de cerdo                  21079799
#                        Carne de pollo                  28342484
#                        Carne de res                    27380376
#                        Carnes otras                      181800
#                        Cerdo en pie                    16426135
#                                                         ...
# VERDURAS Y HORTALIZAS  Tomate chonto                  153649372
#                        Tomate larga vida                3450555
#                        Tomates otros                    2568121
#                        Verduras y hortalizas otras     17978276
#                        Zanahoria                      140644256
# Name: cantidad_kg, Length: 177, dtype: int64

# %%
print('destino_ciudad_mercado: ', len(df['destino_ciudad_mercado'].unique()))
print('procedencia_codigo_departamento: ', len(df['procedencia_codigo_departamento'].unique()))
print('procedencia_codigo_municipio: ' , len(df['procedencia_codigo_municipio'].unique()))
print('procedencia_departamento: ' , len(df['procedencia_departamento'].unique()))
print('procedencia_municipio: ', len(df['procedencia_municipio'].unique()))
print('grupo: ', len(df['grupo'].unique()))
print('alimento: ', len(df['alimento'].unique()))
# Out:
# destino_ciudad_mercado:  29
# procedencia_codigo_departamento:  34
# procedencia_codigo_municipio:  945
# procedencia_departamento:  34
# procedencia_municipio:  969
# grupo:  8
# alimento:  177

# %%
# df_extranjeros = df[df['procedencia_departamento']=='_Importado']
# df_extranjeros.head()

# %%
df.groupby(['procedencia_municipio', 'procedencia_codigo_municipio'])['procedencia_codigo_municipio'].count()
# Out:
# procedencia_municipio       procedencia_codigo_municipio
# ABEJORRAL, ANTIOQUIA        05002                            702
# ABRIAQUÍ, ANTIOQUIA         05004                              3
# ACACÍAS, META               50006                            537
# ACANDÍ, CHOCÓ               27006                              9
# ACEVEDO, HUILA              41006                             31
#                                                             ...
# ZONA BANANERA, MAGDALENA    47980                           2271
# ÁBREGO, NORTE DE SANTANDER  54003                           6225
# ÍQUIRA, HUILA               41357                             16
# ÚMBITA, BOYACÁ              15842                            110
# ÚTICA, CUNDINAMARCA         25851                              4
# Name: procedencia_codigo_municipio, Length: 969, dtype: int64

# %%
# print(len(df_extranjeros['procedencia_municipio'].unique()))
# df_extranjeros['procedencia_municipio'].unique()

# %%
####  IMPORTANTE

# 25 municipios en realidad son paises y corersponden a importaciones,todos con codigo n.a


# hay 998 codigos de municipios de procedencia, de los cuales 1 es n.a IMPORTADO, osea 997 codigos municipios
# hay 949 municipios de procedencia, d elos cuales 25 son paises importados, osea hay realmente 924 municipios

# la diferencua entre 924 municipios y 997 debe atyribuirse a que hay municipios con el mismo nombre (se diferencia en el cod), para este caso 73 repetidos

# %%
# df_extranjeros.groupby(['procedencia_municipio', 'procedencia_codigo_municipio'])['procedencia_codigo_municipio'].count()

# %%
# df[df['procedencia_departamento']=='OTRO'].groupby(['procedencia_municipio', 'procedencia_codigo_municipio'])['procedencia_municipio', 'procedencia_codigo_municipio'].count()

# %%
# df[df['procedencia_departamento']!='OTRO'].groupby(['procedencia_municipio', 'procedencia_codigo_municipio'])['procedencia_municipio', 'procedencia_codigo_municipio'].count()

# %%
df['destino_ciudad']=[mi_ciudad.split(',')[0] for mi_ciudad in df['destino_ciudad_mercado']]

# %%
df['destino_nombre_mercado']=[mi_ciudad.split(',')[-1] for mi_ciudad in df['destino_ciudad_mercado']]
df.head()
# Out:
#   destino_ciudad_mercado       fecha  ... destino_ciudad destino_nombre_mercado
# 0        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 1        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 2        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 3        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 4        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
#
# [5 rows x 12 columns]

# %%
df.head(10)
# Out:
#   destino_ciudad_mercado       fecha  ... destino_ciudad destino_nombre_mercado
# 0        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 1        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 2        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 3        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 4        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 5        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 6        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 7        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 8        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
# 9        Armenia, Mercar  2021-01-02  ...        Armenia                 Mercar
#
# [10 rows x 12 columns]

# %% [markdown]
# ##3.Time standard Cleaning

# %%
print(df.fecha[0])
# print(df.fecha[2100000])
# Out:
# 2021-01-02

# %%
def myDateConv(tt):
    sep = tt[2]
    if sep == '/':
      # print('entra')
      return pd.to_datetime(tt, format='%d/%m/%y')
      
    else:
      # print(tt[0][2])
      return pd.to_datetime(tt, format='%Y-%m-%d %H:%M:%S')


df['fecha_nueva'] = [myDateConv(i) for i in df['fecha']]

# df = df.assign(fecha_nueva = lambda x: (myDateConv(x['fecha'])))
df.head()
# Out:
#   destino_ciudad_mercado       fecha  ... destino_nombre_mercado fecha_nueva
# 0        Armenia, Mercar  2021-01-02  ...                 Mercar  2021-01-02
# 1        Armenia, Mercar  2021-01-02  ...                 Mercar  2021-01-02
# 2        Armenia, Mercar  2021-01-02  ...                 Mercar  2021-01-02
# 3        Armenia, Mercar  2021-01-02  ...                 Mercar  2021-01-02
# 4        Armenia, Mercar  2021-01-02  ...                 Mercar  2021-01-02
#
# [5 rows x 13 columns]

# %%
print(df.fecha_nueva[0])

# print(df.fecha_nueva[2100000])
# Out:
# 2021-01-02 00:00:00

# %%
df['fecha'] = pd.to_datetime(df.fecha_nueva, format='%d/%m/%y %H:%M:%S')



# df.head()

# %%
df['day'] = df['fecha'].dt.day

# %%
df['month'] = df['fecha'].dt.month

# %%
df['year'] = df['fecha'].dt.year

# %%
df.head()
# Out:
#   destino_ciudad_mercado      fecha  ... month  year
# 0        Armenia, Mercar 2021-01-02  ...     1  2021
# 1        Armenia, Mercar 2021-01-02  ...     1  2021
# 2        Armenia, Mercar 2021-01-02  ...     1  2021
# 3        Armenia, Mercar 2021-01-02  ...     1  2021
# 4        Armenia, Mercar 2021-01-02  ...     1  2021
#
# [5 rows x 16 columns]

# %%
df.drop(['fecha_nueva'], inplace=True, axis=1)

# %%
# df.reset_index(inplace=True)
df.head()
# Out:
#   destino_ciudad_mercado      fecha  ... month  year
# 0        Armenia, Mercar 2021-01-02  ...     1  2021
# 1        Armenia, Mercar 2021-01-02  ...     1  2021
# 2        Armenia, Mercar 2021-01-02  ...     1  2021
# 3        Armenia, Mercar 2021-01-02  ...     1  2021
# 4        Armenia, Mercar 2021-01-02  ...     1  2021
#
# [5 rows x 15 columns]

# %%
df.tail()
# Out:
#         destino_ciudad_mercado      fecha  ... month  year
# 1129661     Villavicencio, CAV 2021-08-18  ...     8  2021
# 1129662     Villavicencio, CAV 2021-08-18  ...     8  2021
# 1129663     Villavicencio, CAV 2021-08-18  ...     8  2021
# 1129664     Villavicencio, CAV 2021-08-18  ...     8  2021
# 1129665     Villavicencio, CAV 2021-08-18  ...     8  2021
#
# [5 rows x 15 columns]

# %% [markdown]
# ## CREATE new csv

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
df.to_csv('data_cleaned_2021_step1.csv')
# !cp data_cleaned_2021_step1.csv "/content/drive/MyDrive/Abastecimiento_Proyecto/dataDaneClean"
