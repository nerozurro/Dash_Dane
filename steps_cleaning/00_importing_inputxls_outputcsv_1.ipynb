# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
# uploaded2013 = files.upload()
# uploaded2014 = files.upload()
# uploaded2015 = files.upload()
# uploaded2016 = files.upload()
# uploaded2017 = files.upload()
# uploaded2018 = files.upload()
# uploaded2019 = files.upload()
# uploaded2020 = files.upload()
uploaded2021 = files.upload()
# Out:
#      <input type="file" id="files-67cbbe2b-a5d1-46ac-bdd3-6eb1b7170e7a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67cbbe2b-a5d1-46ac-bdd3-6eb1b7170e7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving microdato-abastecimiento-2021.xlsx to microdato-abastecimiento-2021 (1).xlsx

# %%
from google.colab import files
uploaded2021 = files.upload()
# Out:
#      <input type="file" id="files-a813a63f-cdac-4263-bbf9-ed44ab16d166" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a813a63f-cdac-4263-bbf9-ed44ab16d166">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving microdato-abastecimiento-2021.xlsx to microdato-abastecimiento-2021 (1).xlsx

# %%
import io

xlsx_file = io.BytesIO(uploaded2021['microdato-abastecimiento-2021.xlsx'])
df_2021_1 = pd.read_excel(xlsx_file, '1.1')
df_2021_2 = pd.read_excel(xlsx_file, '1.2')

df_2021 = pd.concat([df_2021_1, df_2021_2])
df_2021.head()
# Out:
#               Unnamed: 0 Unnamed: 1  ... Unnamed: 8 Regresar al índice
# 0                    NaN        NaN  ...        NaN                NaN
# 1        Abastecimiento         NaN  ...        NaN                NaN
# 2                    NaN        NaN  ...        NaN                NaN
# 3  Año 2021 - I semestre        NaN  ...        NaN                NaN
# 4                    NaN        NaN  ...        NaN                NaN
#
# [5 rows x 10 columns]

# %%
xlsx_file = io.BytesIO(uploaded2014['microdato-abastecimiento-2014.xlsx'])
df_2014_1 = pd.read_excel(xlsx_file, '1.1', skiprows=9)
df_2014_2 = pd.read_excel(xlsx_file, '1.2', skiprows=9)

df_2014 = pd.concat([df_2014_1, df_2014_2])
df_2014.head()
# Out:
#   Cuidad, Mercado Mayorista      Fecha  ... Cant Kg Unnamed: 9
# 0  Bogotá, D.C., Corabastos 2014-01-01  ...  3700.0        NaN
# 1  Bogotá, D.C., Corabastos 2014-01-01  ...   700.0        NaN
# 2  Bogotá, D.C., Corabastos 2014-01-01  ...  2500.0        NaN
# 3  Bogotá, D.C., Corabastos 2014-01-01  ...  4150.0        NaN
# 4  Bogotá, D.C., Corabastos 2014-01-01  ...   200.0        NaN
#
# [5 rows x 10 columns]

# %%
xlsx_file = io.BytesIO(uploaded2015['microdato-abastecimiento-2015.xlsx'])
df_2015_1 = pd.read_excel(xlsx_file, '1.1', skiprows=9)
df_2015_2 = pd.read_excel(xlsx_file, '1.2', skiprows=9)

df_2015 = pd.concat([df_2015_1, df_2015_2])
df_2015.head()
# Out:
#       Cuidad, Mercado Mayorista      Fecha  ...  Cant Kg Unnamed: 9
# 0  Barranquilla, Barranquillita 2015-01-01  ...    650.0        NaN
# 1  Barranquilla, Barranquillita 2015-01-01  ...  11750.0        NaN
# 2  Barranquilla, Barranquillita 2015-01-01  ...   1620.0        NaN
# 3  Barranquilla, Barranquillita 2015-01-01  ...    240.0        NaN
# 4  Barranquilla, Barranquillita 2015-01-01  ...    420.0        NaN
#
# [5 rows x 10 columns]

# %%
xlsx_file = io.BytesIO(uploaded2016['microdato-abastecimiento-2016.xlsx'])
df_2016_1 = pd.read_excel(xlsx_file, '1.1', skiprows=9)
df_2016_2 = pd.read_excel(xlsx_file, '1.2', skiprows=9)

df_2016 = pd.concat([df_2016_1, df_2016_2])
df_2016.head()
# Out:
#   Cuidad, Mercado Mayorista      Fecha  ... Unnamed: 9 Unnamed: 10
# 0  Bogotá, D.C., Corabastos 2016-01-01  ...        NaN         NaN
# 1  Bogotá, D.C., Corabastos 2016-01-01  ...        NaN         NaN
# 2  Bogotá, D.C., Corabastos 2016-01-01  ...        NaN         NaN
# 3  Bogotá, D.C., Corabastos 2016-01-01  ...        NaN         NaN
# 4  Bogotá, D.C., Corabastos 2016-01-01  ...        NaN         NaN
#
# [5 rows x 11 columns]

# %%
xlsx_file = io.BytesIO(uploaded2017['microdato-abastecimiento-2017.xlsx'])
df_2017_1 = pd.read_excel(xlsx_file, '1.1', skiprows=9)
df_2017_2 = pd.read_excel(xlsx_file, '1.2', skiprows=9)

df_2017 = pd.concat([df_2017_1, df_2017_2])
df_2017.head()
# Out:
#   Cuidad, Mercado Mayorista      Fecha  ... Cant Kg Unnamed: 9
# 0           Armenia, Mercar 2017-01-02  ...   480.0        NaN
# 1           Armenia, Mercar 2017-01-02  ...  1500.0        NaN
# 2           Armenia, Mercar 2017-01-02  ...  2250.0        NaN
# 3           Armenia, Mercar 2017-01-02  ...  2100.0        NaN
# 4           Armenia, Mercar 2017-01-02  ...   300.0        NaN
#
# [5 rows x 10 columns]

# %%
xlsx_file = io.BytesIO(uploaded2018['microdato-abastecimiento-2018.xlsx'])
df_2018_1 = pd.read_excel(xlsx_file, '1.1', skiprows=9)
df_2018_2 = pd.read_excel(xlsx_file, '1.2', skiprows=9)

df_2018 = pd.concat([df_2018_1, df_2018_2])
df_2018.head()
# Out:
#   Cuidad, Mercado Mayorista      Fecha  ... Unnamed: 9 Unnamed: 10
# 0           Armenia, Mercar 2018-01-02  ...        NaN         NaN
# 1           Armenia, Mercar 2018-01-02  ...        NaN         NaN
# 2           Armenia, Mercar 2018-01-02  ...        NaN         NaN
# 3           Armenia, Mercar 2018-01-02  ...        NaN         1.0
# 4           Armenia, Mercar 2018-01-02  ...        NaN         NaN
#
# [5 rows x 11 columns]

# %%
xlsx_file = io.BytesIO(uploaded2019['microdato-abastecimiento-2019.xlsx'])
df_2019_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
df_2019_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

df_2019 = pd.concat([df_2019_1, df_2019_2])
df_2019.head()
# Out:
#   Cuidad, Mercado Mayorista      Fecha  ...  Cant Kg Unnamed: 9
# 0           Armenia, Mercar 2019-01-02  ...  10000.0        NaN
# 1           Armenia, Mercar 2019-01-02  ...  10000.0        NaN
# 2           Armenia, Mercar 2019-01-02  ...   1600.0        NaN
# 3           Armenia, Mercar 2019-01-02  ...   1000.0        NaN
# 4           Armenia, Mercar 2019-01-02  ...   6000.0        NaN
#
# [5 rows x 10 columns]

# %%
xlsx_file = io.BytesIO(uploaded2020['microdato-abastecimiento-2020.xlsx'])
df_2020_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
df_2020_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

df_2020 = pd.concat([df_2020_1, df_2020_2])
df_2020.head()
# Out:
#   Cuidad, Mercado Mayorista     Fecha  ...  Cant Kg Unnamed: 9
# 0           Armenia, Mercar  02/01/20  ...   3000.0        NaN
# 1           Armenia, Mercar  02/01/20  ...   7000.0        NaN
# 2           Armenia, Mercar  02/01/20  ...  10000.0        NaN
# 3           Armenia, Mercar  02/01/20  ...   1500.0        NaN
# 4           Armenia, Mercar  02/01/20  ...   6000.0        NaN
#
# [5 rows x 10 columns]

# %%
import io
xlsx_file = io.BytesIO(uploaded2021['microdato-abastecimiento-2021.xlsx'])
df_2021_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
df_2021_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

df_2021 = pd.concat([df_2021_1, df_2021_2])
df_2021.head()
# Out:
#   Cuidad, Mercado Mayorista      Fecha  ...  Cant Kg Unnamed: 9
# 0           Armenia, Mercar 2021-01-02  ...   3240.0        NaN
# 1           Armenia, Mercar 2021-01-02  ...  15640.0        NaN
# 2           Armenia, Mercar 2021-01-02  ...   8000.0        NaN
# 3           Armenia, Mercar 2021-01-02  ...   2000.0        NaN
# 4           Armenia, Mercar 2021-01-02  ...  10000.0        NaN
#
# [5 rows x 10 columns]

# %%
df_2013_1=[]
df_2013_2=[]
df_2014_1=[]
df_2014_2=[]
df_2015_1=[]
df_2015_2=[]

df_2016_1=[]
df_2016_2=[]
df_2017_1=[]
df_2017_2=[]
df_2018_1=[]
df_2018_2=[]

df_2019_1=[]
df_2019_2=[]
df_2020_1=[]
df_2020_2=[]
df_2021_1=[]
df_2021_2=[]

# %%
# import io

# xlsx_file = io.BytesIO(uploaded1['microdato-abastecimiento-2013.xlsx'])
# df_2013_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
# df_2013_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

# xlsx_file = io.BytesIO(uploaded1['microdato-abastecimiento-2014.xlsx'])
# df_2014_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
# df_2014_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

# xlsx_file = io.BytesIO(uploaded1['microdato-abastecimiento-2015.xlsx'])
# df_2015_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
# df_2015_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

# xlsx_file = io.BytesIO(uploaded1['microdato-abastecimiento-2016.xlsx'])
# df_2016_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
# df_2016_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

# xlsx_file = io.BytesIO(uploaded1['microdato-abastecimiento-2017.xlsx'])
# df_2017_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
# df_2017_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

# xlsx_file = io.BytesIO(uploaded1['microdato-abastecimiento-2018.xlsx'])
# df_2018_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
# df_2018_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

# xlsx_file = io.BytesIO(uploaded1['microdato-abastecimiento-2019.xlsx'])
# df_2019_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
# df_2019_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

# xlsx_file = io.BytesIO(uploaded1['microdato-abastecimiento-2020.xlsx'])
# df_2020_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
# df_2020_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

# xlsx_file = io.BytesIO(uploaded2['microdato-abastecimiento-2021.xlsx'])
# df_2021_1 = pd.read_excel(xlsx_file, '1.1', skiprows=8)
# df_2021_2 = pd.read_excel(xlsx_file, '1.2', skiprows=8)

# df_first_sheet.head()

# %%
print(len(df_2013))
print(len(df_2014))
print(len(df_2015))
print(len(df_2016))
print(len(df_2017))
print(len(df_2018))
print(len(df_2019))
print(len(df_2020))
print(len(df_2021))
# Out:
# 1046815
# 1099581
# 1177640
# 1230868
# 1365884
# 1727577
# 1805560
# 1813661
# 816447

# %%
# df = pd.concat([df_2020_1, df_2020_2, df_2021_1])

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# save each year in a different file

df_2013.to_csv('abastecimiento_2013.csv')
# !cp abastecimiento_2013.csv "drive/My Drive/"

# %%
df_2014.to_csv('abastecimiento_2014.csv')
# !cp abastecimiento_2014.csv "drive/My Drive/"

# %%
df_2015.to_csv('abastecimiento_2015.csv')
# !cp abastecimiento_2015.csv "drive/My Drive/"

# %%
df_2016.to_csv('abastecimiento_2016.csv')
# !cp abastecimiento_2016.csv "drive/My Drive/"

# %%
df_2017.to_csv('abastecimiento_2017.csv')
# !cp abastecimiento_2017.csv "drive/My Drive/"

# %%
df_2018.to_csv('abastecimiento_2018.csv')
# !cp abastecimiento_2018.csv "drive/My Drive/"

# %%
df_2019.to_csv('abastecimiento_2019.csv')
# !cp abastecimiento_2019.csv "drive/My Drive/"

# %%
df_2020.to_csv('abastecimiento_2020.csv')
# !cp abastecimiento_2020.csv "drive/My Drive/"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ca6274dc59fd> in <module>()
# ----> 1 df_2020.to_csv('abastecimiento_2020.csv')
#       2 get_ipython().system('cp abastecimiento_2020.csv "drive/My Drive/"')
#       3
#
# NameError: name 'df_2020' is not defined

# %%
df_2021.to_csv('abastecimiento_2021.csv')
# !cp abastecimiento_2021.csv "drive/My Drive/"

# %%
df = pd.concat([df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021])
print(len(df))

# %%
df.to_csv('data_full_years.csv')
# !cp data_full_years.csv "drive/My Drive/"
